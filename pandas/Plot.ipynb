# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
columns=list('ABCD'),
index=np.arange(0, 100, 10))
print(df)
df.plot()
# Out:
#            A         B         C         D
# 0   0.620091 -1.793849 -0.494396 -0.001463
# 10  0.788875 -0.773252 -0.083144  0.640016
# 20  0.288055  0.721986 -1.146307  0.636756
# 30  1.446379  1.672930 -0.778097 -0.102051
# 40  1.831270  0.676162 -0.999759  1.521065
# 50  0.965522  1.591333 -2.133621 -0.133143
# 60  1.070638  3.679568 -2.844252 -0.371827
# 70  1.169231  4.608684 -3.272321  0.516617
# 80  0.902771  4.761869 -4.958793  1.387426
# 90  0.916472  6.053836 -5.182730 -0.167434
# <AxesSubplot:>

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(color='k', alpha=0.7)#条形图
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4),
index=['one', 'two', 'three', 'four', 'five', 'six'],
columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
#使用了列索引，故颜色不同
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha=0.5)#提高空间利用率
# Out:
# <AxesSubplot:>

# %%
comp1 = np.random.normal(0, 1, size=200)#正态分布
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values,hist=True,kde=True,bins=100)#hist是直方图，kde是核密度，bins是分成的区间数
# Out:
# c:\Users\19234\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
data = pd.DataFrame(np.random.randint(low=1,high=10,size=(4,1)))
data
# Out:
#    0
# 0  7
# 1  7
# 2  6
# 3  7

# %%
data.diff()#前后差异
# Out:
#      0
# 0  NaN
# 1  0.0
# 2 -1.0
# 3  1.0

# %%
macro = pd.read_csv('csv/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]#对数差分，dropna滤除缺失数据
sns.regplot('m1', 'unemp', data=trans_data)#线性回归
# Out:
# c:\Users\19234\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %%
sns.pairplot(trans_data,diag_kind='kde',plot_kws={'alpha': 0.2})
#对角线上是分布图,diag_kind有"hist"与"kde"
#kind是非对角线，有"scatter"与"reg"

# %%
trans_data['tbilrate']
# Out:
# 1      0.088193
# 2      0.215321
# 3      0.125317
# 4     -0.212805
# 5     -0.266946
#          ...
# 198   -0.396881
# 199   -2.277267
# 200    0.606136
# 201   -0.200671
# 202   -0.405465
# Name: tbilrate, Length: 202, dtype: float64

# %%
a=[66.0,
70.3,
74.7,
74.9
]
ay=[0.258,
0.220,
0.148,
0.070
]
b=[0,	40,	60,	80,	100,	120,	140,	160,	180,	200,	220,	230]
by=[0,	0.08,	0.11,	0.12,	0.13,	0.14,	0.15,	0.16,	0.17,	0.18,	0.19,	0.20]
c=[0,	40,	60,	80,	100,	120,	140,	160,	180,	200,	220,	230]
cy=[0,	0.04,	0.07,	0.11,	0.13,	0.16,	0.18,	0.21,	0.23,	0.26,	0.28,	0.29]
import plotly.graph_objects as go
fig=go.Figure()
fig.update_layout(title="荧光灯管的“负阻态”伏安特性曲线",xaxis_title='灯管电压U3',yaxis_title='灯电流 I')
fig.add_trace(go.Scatter(x=a,y=ay,name='电阻器'))
