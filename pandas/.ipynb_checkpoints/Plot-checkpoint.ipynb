# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
columns=list('ABCD'),
index=np.arange(0, 100, 10))
print(df)
df.plot()
# Out:
# A         B         C         D
# 0   0.640744 -0.177221  1.190072  1.723964
# 10  1.933549 -1.520908  0.764290  2.181812
# 20  0.754856 -1.246928 -0.002899  1.700228
# 30  1.465721 -0.952344  1.953467  1.608748
# 40  1.315876  0.402855  1.434382  0.835656
# 50  0.588620 -1.509589 -0.802638 -0.956369
# 60  1.115554 -1.903512  0.960641 -1.697426
# 70  1.178177 -1.709584  1.297533 -0.688559
# 80  1.982084 -1.188378  2.440907 -0.929502
# 90  1.158963 -0.688621  2.659123 -1.828325

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(color='k', alpha=0.7)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
index=['one', 'two', 'three', 'four', 'five', 'six'],
columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
#使用了列索引，故颜色不同
df.plot.bar()

# %%
df.plot.barh(stacked=True, alpha=0.5)#提高空间利用率

# %%
comp1 = np.random.normal(0, 1, size=200)#正态分布
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values,hist=True,kde=True,bins=100)#hist是直方图，kde是核密度，bins是分成的区间数

# %%
data = pd.DataFrame(np.random.randint(low=1,high=10,size=(4,1)))
data
# Out:
#    0
# 0  1
# 1  3
# 2  4
# 3  9

# %%
data.diff()#前后差异
# Out:
#      0
# 0  NaN
# 1  2.0
# 2  1.0
# 3  5.0

# %%
macro = pd.read_csv('csv/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]#对数差分，dropna滤除缺失数据
sns.regplot('m1', 'unemp', data=trans_data)#线性回归

# %%
sns.pairplot(trans_data,diag_kind='kde',plot_kws={'alpha': 0.2})
#对角线上是分布图,diag_kind有"hist"与"kde"
#kind是非对角线，有"scatter"与"reg"
