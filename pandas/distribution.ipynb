# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import math

# %%
s = pd.Series(np.random.randint(35,46,size=10), index=np.arange(0, 10, 1))/10#左闭右开
s
# Out:
# 0    4.3
# 1    4.3
# 2    3.7
# 3    4.3
# 4    3.5
# 5    3.8
# 6    4.4
# 7    4.2
# 8    4.4
# 9    4.0
# dtype: float64

# %% [markdown]
# $\rm np.random.randint\,\,[Min,Max)$

# %%
s1=pd.Series(1000)
i=1
s1[0]=4#有bug
while(i<1000):
    t=sum(np.random.randint(35,46,size=4)/40)
    if(t>3.5 and t<4.5):
        s1[i]=t
        i=i+1
    else:
        pass
s1.plot()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(s1,hist=True,kde=True,bins=20)
# Out:
# c:\Users\19234\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# 正态分布函数为
#
# $p(x)=\frac{1}{\sigma \sqrt{2 \pi}} \cdot e^{-\frac{(x-\mu)^{2}}{2 \sigma^{2}}}$
#
# 期望值μ决定了其位置，其标准差σ决定了分布的幅度
#
# 其中标准差$\sigma$为$\sigma_{n}=\sqrt{\frac{\left(x_{1}-\bar{x}\right)^{2}+\left(x_{2}-\bar{x}\right)^{2}+\cdots+\left(x_{n}-\bar{x}\right)^{2}}{n}}$

# %%
#二项分布
#distplot 为直方图
n=20
nums=[]
p=0.7

import math
for i in range(n):
    nums.append(round(100*math.comb(n-1,i)*np.power(p,i)*np.power(1-p,n-i)))
Li=np.repeat(range(n),nums)
S=pd.Series(Li)
sns.distplot(S)
# Out:
# c:\Users\19234\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(S,shade=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
u = 0  # 均值μ
u01 = -2
sig = math.sqrt(0.2)  # 标准差δ

x = np.linspace(u - 3 * sig, u + 3 * sig, 50)
y_sig1 = np.exp(-(x - u) ** 2 / (2 * sig ** 2)) / (math.sqrt(2 * math.pi) * sig)

sig = math.sqrt(0.4)  

y_sig2 = np.exp(-(x - u) ** 2 / (2 * sig ** 2)) / (math.sqrt(2 * math.pi) * sig)

plt.plot(x, y_sig1, "r-", label=r"$\sqrt{0.2}$")
plt.plot(x, y_sig2, "b-",label=r"$\sqrt{2}$")
plt.legend(loc='upper right')#一定要加
plt.grid(True)
plt.show()

# %% [markdown]
# 我们发现，方差越小越接近于均值

# %%
s = pd.Series(np.random.randint(35,46,size=4000))/10#左闭右开
s.var()
# Out:
# 0.10144670605151289

# %%
s1.var()
# Out:
# 0.02454327765265266

# %% [markdown]
# 四个求均值
#
# $4\sigma _1^2=\sigma^2$

# %% [markdown]
# 如果

# %%
s2=pd.Series(250)
i=1
s2[0]=4#有bug
while(i<250):
    t=sum(np.random.randint(35,46,size=16)/160)
    if(t>3.5 and t<4.5):
        s2[i]=t
        i=i+1
    else:
        pass
s2.plot()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(s2,hist=True,kde=True,bins=20)
# Out:
# c:\Users\19234\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
s2.var()
# Out:
# 0.006169952309236949

# %%
s2.var()*16
# Out:
# 0.09871923694779118

# %% [markdown]
# 十六个求均值
#
# $16\sigma _1^2=\sigma^2$

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
#   $X_{1}$, $X_{2}$, $\ldots$, $X_{n}$  他们彼此之间满足独立同分布, 因此他们拥有相同 的均值  $\mu $ 和方差 $ \sigma^{2} $
#
# 我们有如下的随机变量：此时, 我们重点来研究这一组随机变量的均值: $ M_{n}=\frac{X_{1}+X_{2}+\ldots+X_{n}}{n}$
#
# 它的均值为
#
# $E\left[M_{n}\right]=E\left[\frac{X_{1}+X_{2}+\ldots+X_{n}}{n}\right]=\frac{1}{n}\left(E\left[X_{1}\right]+E\left[X_{2}\right]+\ldots+E\left[X_{n}\right]\right)=\frac{1}{n} \cdot n \cdot \mu=\mu=E\left[X_{i}]\right.$
#
# 它的方差为
#
# $\begin{array}{l}
# \operatorname{var}\left[M_{n}\right]=\operatorname{var}\left[\frac{X_{1}+X_{2}+\ldots+X_{n}}{n}\right]=\frac{1}{n^{2}} \operatorname{var}\left[X_{1}+X_{2}+\ldots+X_{n}\right] \\
# =\frac{1}{n^{2}}\left(\operatorname{var}\left[X_{1}\right]+\operatorname{var}\left[X_{2}\right]+\ldots+\operatorname{var}\left[X_{n}\right]\right)=\frac{1}{n^{2}} \cdot n \cdot \sigma^{2}=\frac{\sigma^{2}}{n}
# \end{array}$
#
# $\bar{X}_{n} \stackrel{d}{\rightarrow} N\left(\mu, \frac{\sigma^{2}}{n}\right)$
#
# 这就是中心极限定理
