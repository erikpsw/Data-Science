# %%
import numpy as np
import pandas as pd
import cufflinks as cf

D=pd.DataFrame(np.random.randn(25,4),columns=['a','b','c','d'])
D.plot()
# Out:
# <AxesSubplot:>

# %%
cf.datagen.lines(1,500).ta_plot(study='sma',periods=[13,21,55])
# Out:
# <div>                            <div id="121d6924-a173-4db4-9d68-c967583cf41e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
D.iplot()
# Out:
# <div>                            <div id="d9e60546-391c-4e0b-98b3-6e77695c6706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
