# %%
X=[	1439323776,
1406847870,
1368810615,
1330776380,
1290550765,
1240920535,
1176883674,
1075589361,
1000089235,
926240885,
827601394,
724218968,
660408056,
612241554
]
import pandas as pd
import numpy as np
import cufflinks as cf
X.reverse()
years=[]
for i in range(len(X)):
    years.append(1955+5*i)
pd.DataFrame(X,index=years).iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="bf56a742-a1fd-4de5-8356-027a31e51f6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
X=np.linspace(0,3,1000)
Y1=np.power(np.e,X) 
Y2=np.power(np.e,X-0.2*np.power(X,2)) 
import plotly.graph_objects as go
fig=go.Figure()
fig.add_trace(go.Scatter(x=X,y=Y1,name='原始')) 
fig.add_trace(go.Scatter(x=X,y=Y2,name='改进'))
# Out:
# <div>                            <div id="ea15144d-8edd-463d-97f7-15c8f2af14de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea15144d-8edd-463d-97f7-15c8f2af14de")) {                    Plotly.newPlot(                        "ea15144d-8edd-463d-97f7-15c8f2af14de",                        [{"name":"\u539f\u59cb","x":[0.0,0.003003003003003003,0.006006006006006006,0.009009009009009009,0.012012012012012012,0.015015015015015015,0.018018018018018018,0.02102102102102102,0.024024024024024024,0.02702702702702703,0.03003003003003003,0.03303303303303303,0.036036036036036036,0.03903903903903904,0.04204204204204204,0.04504504504504504,0.04804804804804805,0.05105105105105105,0.05405405405405406,0.057057057057057055,0.06006006006006006,0.06306306306306306,0.0660
# ...

# %%
X=np.linspace(0,100,1000)
xm=3
r=0.05
Y1=xm/(1+((xm)-1)*np.power(np.e,-r*X))

import plotly.graph_objects as go
fig=go.Figure()
fig.add_trace(go.Scatter(x=X,y=Y1,name='原始'))
# Out:
# <div>                            <div id="8220eb0b-60d8-4a28-95f7-9a6c07bcaf45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8220eb0b-60d8-4a28-95f7-9a6c07bcaf45")) {                    Plotly.newPlot(                        "8220eb0b-60d8-4a28-95f7-9a6c07bcaf45",                        [{"name":"\u539f\u59cb","x":[0.0,0.1001001001001001,0.2002002002002002,0.3003003003003003,0.4004004004004004,0.5005005005005005,0.6006006006006006,0.7007007007007008,0.8008008008008008,0.9009009009009009,1.001001001001001,1.1011011011011012,1.2012012012012012,1.3013013013013013,1.4014014014014016,1.5015015015015016,1.6016016016016017,1.7017017017017018,1.8018018018018018,1.9019019019019021,2.002002002002002,2.1021021021021022,2.2022022022022023,2.3023023023023024,
# ...
